# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

plt.plot(x,y)
plt.title("First Title")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.show()
# Out:
# C:\Users\lanka\AppData\Local\Temp\ipykernel_23368\2891639132.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
